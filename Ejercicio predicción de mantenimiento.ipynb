# %% [markdown]
# #STEVEN ARTOS
#
# #COMENTARIOS AL FINAL DEL COLAB
#
# #EJERCICIO PREDICCION DE MANTENIMIENTO

# %%
#importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets,linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import StandardScaler
from math import sqrt

# %%
#conectar al drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#subir csv
data=pd.read_csv('/content/drive/MyDrive/ARCHIVOS CURSO PYTHON/dataset_mantenimiento.csv')

# %%
data.head()
# Out:
#    horas_operación  temperatura_promedio  vibración  ...  uso_diario  fallas_previas  tiempo_fallo
# 0      5930.831723             90.543269   1.331688  ...   16.767144               6   1211.812521
# 1     14285.357443            101.701326   0.427534  ...   11.754132               7    808.990807
# 2     11113.912156             52.542111   1.757550  ...    2.281259               4   1093.712364
# 3      9180.548021             86.238669   1.264921  ...   22.125733               2   1178.842600
# 4      2762.270286             81.457138   0.398687  ...   23.547570              10   1524.159687
#
# [5 rows x 11 columns]

# %%
X=data.drop(columns=['tiempo_fallo']) #x todas menos tiempo de fallo
Y=data['tiempo_fallo'] # y tiempo de fallo

# %%
X
# Out:
#       horas_operación  temperatura_promedio  vibración  ...  edad_equipo  uso_diario  fallas_previas
# 0         5930.831723             90.543269   1.331688  ...    15.677537   16.767144               6
# 1        14285.357443            101.701326   0.427534  ...    10.141743   11.754132               7
# 2        11113.912156             52.542111   1.757550  ...    15.990208    2.281259               4
# 3         9180.548021             86.238669   1.264921  ...     2.396657   22.125733               2
# 4         2762.270286             81.457138   0.398687  ...     4.640285   23.547570              10
# ...               ...                   ...        ...  ...          ...         ...             ...
# 2995     13046.788504             91.599182   1.078366  ...    18.352790    8.558496               9
# 2996      2780.461519             75.289837   0.414204  ...     9.140989   12.035864               2
# ...

# %%
Y
# Out:
# 0       1211.812521
# 1        808.990807
# 2       1093.712364
# 3       1178.842600
# 4       1524.159687
#            ...
# 2995     633.026234
# 2996    1433.928938
# 2997     571.571954
# 2998     648.257052
# 2999     969.551166
# Name: tiempo_fallo, Length: 3000, dtype: float64

# %%
from os import X_OK
#DIVIDIR TEST Y TRAIN 80% TRAIN 20% TEST
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=29)
#EL RANDON 29  VA SERVIR PARA REALIZAR LAS OPERACIONES DE NUEVO Y QUE NO SE MODIFIQUE

# %%
#NORMALIZAR
scaler=StandardScaler()
scaler.fit(X_train)
X_train_normalized=scaler.transform(X_train)
X_test_normalized=scaler.transform(X_test)

# %%
#crear modelo
regr=linear_model.LinearRegression()
regr.fit(X_train_normalized,Y_train)
# Out:
# LinearRegression()

# %%
#prediccion
y_pred=regr.predict(X_test_normalized)

# %%
mse=mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)

# %%
print(f"error cuadratico medio: {mse}")
print(f"error cuadratico medio: {sqrt(mse)}")
print(f"coeficiente de determinacion: {r2}")
# Out:
# error cuadratico medio: 846.2739005563785
# error cuadratico medio: 29.090787211011985
# coeficiente de determinacion: 0.9970877177339401

# %%
feature_names=[
    "horas_operacion",
    "temperatura_promedio",
    "vibracion","presion_sistema","carga_promedio",
    "humedad_ambiente","frecuencia_mantenimiento","edad_equipo","uso_diario",
    "fallas_previas"
]

# %%
#imprimir cada coef
print("Coeficientes de cada caracteristica:")
for feature,coef in zip(feature_names,regr.coef_):
  print(f"{feature}: {coef:4f}")
# Out:
# Coeficientes de cada caracteristica:
# horas_operacion: -4.603670
# temperatura_promedio: 12.995598
# vibracion: 42.434199
# presion_sistema: -39.610542
# carga_promedio: -18.555674
# humedad_ambiente: 5.151329
# frecuencia_mantenimiento: 509.761470
# edad_equipo: 39.148293
# uso_diario: -79.454772
# fallas_previas: 79.337371

# %% [markdown]
# #COMENTARIOS DE EJERCICIO
#
# #La finalidad del ejercicio era predecir el tiempo de fallo de un equipo industrial utilizando un modelo de regresión lineal. Se analizaron datos de operación como temperatura, vibración, presión y frecuencia de mantenimiento para encontrar patrones que permitan estimar cuándo ocurrirá una falla.
#
#
# #A través de pandas y numpy, se realizó una eficiente manipulación y exploración de datos, permitiendo una adecuada preparación del conjunto de información. Con scikit-learn, se implementaron técnicas clave como la división en conjuntos de entrenamiento y prueba (train_test_split), la normalización de datos (StandardScaler), y la construcción de un modelo de regresión lineal (LinearRegression).
#
# #El uso de estas herramientas permitió desarrollar un enfoque analítico basado en datos, facilitando la toma de decisiones estratégicas en la planificación del mantenimiento. La combinación de manipulación de datos, preprocesamiento, modelado predictivo y evaluación de métricas demuestra el valor del análisis de datos para la optimización operativa y la reducción de costos en entornos industriales.
